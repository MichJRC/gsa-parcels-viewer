# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
import os
print("Current directory:", os.getcwd())
print("Files in current directory:", os.listdir('.'))
# Out:
# Current directory: /workspaces/gsa-parcels-viewer/pre_process_scripts
# Files in current directory: ['analysing_dataset_duplicates.py', 'clean_dataset.py', 'GSA_to_HRL_AGRICULTURAL_ONLY.csv', 'GSA_to_HRL_mapping_FINAL_v2.csv', 'GSA_codes_STILL_NEED_REVIEW.csv', 'flaskViewerApp.py', 'HRL_summary.csv', 'parcel_viewer.html', 'read_plot_dataset.py', 'GSA_codes_STILL_NEED_REVIEW_v2.csv', 'test_setup.py', 'plots.ipynb', 'apply_manual_corrections.py', 'merging_HRL_classes.py', 'GSA_to_HRL_mapping_FINAL.csv', 'test_polygons.py', 'plot.png', 'shape_index_visual.png', 'GSA_to_HRL_AGRICULTURAL_ONLY_v2.csv', 'HRL_distribution_summary.csv', 'top_20_crops_by_area.csv', 'apply_hrl_to_gpkg.py', 'HRL_summary_v2.csv']

# %%
df = gpd.read_file("/workspaces/gsa-parcels-viewer/downloaded_data/parcels_with_HRL_codes.gpkg")

# %%
df.columns
# Out:
# Index(['ANNO_CAMP', 'COD_AZI', 'DT_DICH', 'DATA_RIF', 'CODI_REGI',
#        'ISTAT_PROV', 'SIGLA_PROV', 'ISTAT_COMU', 'CODI_ISOL', 'ID_APPEZ',
#        'COD_SUOLO', 'DESC_SUOLO', 'COD_DEST', 'DESC_DEST', 'COD_QUAL',
#        'DESC_QUAL', 'COD_USO', 'DESC_USO', 'COD_MACRO', 'DESC_MACRO',
#        'COD_CATE', 'DESC_CATE', 'COD_COLT', 'DESC_COLT', 'COD_VARI',
#        'DESC_VARI', 'COD_VARI2', 'DESC_VARI2', 'PERC_VARI2', 'COD_BIO',
#        'DESC_BIO', 'COD_MANTE', 'DESC_MANTE', 'FLAG_SAU', 'COD_SERRA',
#        'DESC_SERRA', 'COD_SEMIN', 'DESC_SEMIN', 'COD_PROTE', 'DESC_PROTE',
#        'COD_IRRIG', 'DESC_IRRIG', 'ANNO_IMPI', 'SESTO_SU_F', 'SESTO_TR_F',
#        'COD_IMPIA', 'DESC_IMPIA', 'NUM_PIANTE', 'DENS_PIANT', 'COD_FA_AL',
#        'DESC_FA_AL', 'COD_FO_AL', 'DESC_FO_AL', 'COD_CE_OL', 'DESC_CE_OL',
#        'COD_MENZ', 'DESC_MENZ', 'PROD_MEDIA', 'FLAG_APPE2', 'SUP_APPEZ',
#        'DT_IN_APPE', 'DT_FI_APPE', 'hrl_code', 'hrl_name', 'geometry'],
#       dtype='object')

# %%
df.loc[0,'geometry']
# Out:
# <MULTIPOLYGON (((1726101.275 4969902.18, 1726408.12 4970040.404, 1726406.836...>

# %%
print(df.loc[0,'geometry'])
# Out:
# MULTIPOLYGON (((1726101.27507785 4969902.17966265, 1726408.12042708 4970040.40429549, 1726406.83598651 4970011.4238636, 1726399.844 4969940.698, 1726388.549 4969897.671, 1726389.356 4969892.024, 1726394.035 4969886.513, 1726417.375 4969886.331, 1726457.233 4969778.373, 1726501.97087282 4969663.61154991, 1726415.6170253 4969613.0098472, 1726413.69647297 4969616.42099975, 1726411.41275126 4969616.59667065, 1726410.51227495 4969610.22404541, 1726412.08999974 4969624.01000271, 1726411.1099999999 4969634.3100000005, 1726406.2902 4969653.037372, 1726400.5196 4969662.483751, 1726390.75569902 4969698.2588244, 1726363.22582288 4969760.27182117, 1726215.6 4969740.84, 1726197.85 4969776.09, 1726165.59759 4969824.274814, 1726142.271999 4969855.568391, 1726101.27507785 4969902.17966265)))

# %%
df.plot()
plt.show()

# %%
df.crs
# Out:
# <Projected CRS: EPSG:3003>
# Name: Monte Mario / Italy zone 1
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Italy - onshore and offshore - west of 12°E.
# - bounds: (5.93, 36.53, 12.0, 47.04)
# Coordinate Operation:
# - name: Italy zone 1
# - method: Transverse Mercator
# Datum: Monte Mario
# - Ellipsoid: International 1924
# - Prime Meridian: Greenwich
